# %%
import chromadb

client=chromadb.Client()
collection=client.create_collection(name="my_collection")

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids=['id1','id2']
)
# Out:
# C:\Users\admin\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz:   1%|▉                                                                                             | 849k/79.3M [01:55<3:01:34, 7.56kiB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 collection.add(
#       2     documents=[
#       3         "This document is about New York",
#       4         "This document is about Delhi"
#       5     ],
#       6     ids=['id1','id2']
#       7 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\models\Collection.py:82, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#      47 def add(
#      48     self,
#      49     ids: OneOrMany[ID],
#    (...)
#      59     uris: Optional[OneOrMany[URI]] = None,
#      60 ) -> None:
#      61     """Add embeddings to the data store.
#      62     Args:
#      63         ids: The ids of the embeddings you wish to add
#    (...)
#      79
#      80     """
# ---> 82     add_request = self._validate_and_prepare_add_request(
#      83         ids=ids,
#      84         embeddings=embeddings,
#      85         metadatas=metadatas,
#      86         documents=documents,
#      87         images=images,
#      88         uris=uris,
#      89     )
#      91     self._client._add(
#      92         collection_id=self.id,
#      93         ids=add_request["ids"],
#    (...)
#      99         database=self.database,
#     100     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\models\CollectionCommon.py:90, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      87 @functools.wraps(func)
#      88 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#      89     try:
# ---> 90         return func(self, *args, **kwargs)
#      91     except Exception as e:
#      92         msg = f"{str(e)} in {name}."
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\models\CollectionCommon.py:213, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     211 if add_records["embeddings"] is None:
#     212     validate_record_set_for_embedding(record_set=add_records)
# --> 213     add_embeddings = self._embed_record_set(record_set=add_records)
#     214 else:
#     215     add_embeddings = add_records["embeddings"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\models\CollectionCommon.py:526, in CollectionCommon._embed_record_set(self, record_set, embeddable_fields)
#     522             return self._embed(
#     523                 input=self._data_loader(uris=cast(URIs, record_set[field]))  # type: ignore[literal-required]
#     524             )
#     525         else:
# --> 526             return self._embed(input=record_set[field])  # type: ignore[literal-required]
#     527 raise ValueError(
#     528     "Record does not contain any non-None fields that can be embedded."
#     529     f"Embeddable Fields: {embeddable_fields}"
#     530     f"Record Fields: {record_set}"
#     531 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\models\CollectionCommon.py:539, in CollectionCommon._embed(self, input)
#     534 if self._embedding_function is None:
#     535     raise ValueError(
#     536         "You must provide an embedding function to compute embeddings."
#     537         "https://docs.trychroma.com/guides/embeddings"
#     538     )
# --> 539 return self._embedding_function(input=input)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\api\types.py:466, in EmbeddingFunction.__init_subclass__.<locals>.__call__(self, input)
#     465 def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 466     result = call(self, input)
#     467     assert result is not None
#     468     return validate_embeddings(cast(Embeddings, normalize_embeddings(result)))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:199, in ONNXMiniLM_L6_V2.__call__(self, input)
#     197 def __call__(self, input: Documents) -> Embeddings:
#     198     # Only download the model when it is actually used
# --> 199     self._download_model_if_not_exists()
#     200     return cast(Embeddings, self._forward(input))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:226, in ONNXMiniLM_L6_V2._download_model_if_not_exists(self)
#     219 os.makedirs(self.DOWNLOAD_PATH, exist_ok=True)
#     220 if not os.path.exists(
#     221     os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME)
#     222 ) or not _verify_sha256(
#     223     os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     224     self._MODEL_SHA256,
#     225 ):
# --> 226     self._download(
#     227         url=self.MODEL_DOWNLOAD_URL,
#     228         fname=os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     229     )
#     230 with tarfile.open(
#     231     name=os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#     232     mode="r:gz",
#     233 ) as tar:
#     234     tar.extractall(path=self.DOWNLOAD_PATH)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:109, in ONNXMiniLM_L6_V2._download(self, url, fname, chunk_size)
#     101 total = int(resp.headers.get("content-length", 0))
#     102 with open(fname, "wb") as file, self.tqdm(
#     103     desc=str(fname),
#     104     total=total,
#    (...)
#     107     unit_divisor=1024,
#     108 ) as bar:
# --> 109     for data in resp.iter_bytes(chunk_size=chunk_size):
#     110         size = file.write(data)
#     111         bar.update(size)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1259, in SSLSocket.recv(self, buflen, flags)
#    1255     if flags != 0:
#    1256         raise ValueError(
#    1257             "non-zero flags not allowed in calls to recv() on %s" %
#    1258             self.__class__)
# -> 1259     return self.read(buflen)
#    1260 else:
#    1261     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130         return self._sslobj.read(len, buffer)
#    1131     else:
# -> 1132         return self._sslobj.read(len)
#    1133 except SSLError as x:
#    1134     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
all_docs=collection.get()
all_docs
